# %% [markdown]
# # Prelude

# %%
from pysat.formula import CNF
from pysat.solvers import *
import re
import pandas as pd
import os

CONFIG_DIR = "../linux-4.14.152"
DIMACS_FLA = 'examples/out.dimacs'
CONFIG = "../linux-4.14.152/.config"
CONF_FLAG = ["randconfig", "defconfig", "allnoconfig", "allyesconfig", "allmodconfig", "alldefconfig"]
SOLU_SIZE = 1000 # Initial number of solutions to extract

# %% [markdown]
# # Loading data

# %%
#
#
variables = {}
with open(DIMACS_FLA, 'r') as f:
    dimacs_lines = f.readlines()
    for line in dimacs_lines:
        if line.startswith("c"):
            m = re.search('(c) (\d+) (\w+)', line)
            var_id = int(m.group(2))
            var_name = m.group(3)  
            variables[var_id] = var_name
            
def search_kconfig_type(option_name, df_options):
    ktype = df_options.query("option == " + '"' + option_name + '"')['type']
    return ktype.values[0]

# we are thinking the DIMACS id (number k) corresponding to the "module" variable of an option
def search_kmodule(option_name):
    for k, v in variables.items():
        if v == option_name + "_MODULE":
            return k

# Build a dict {option: val} from .config file
def get_dict(filename):
    res = dict()
    with open(filename, 'r') as f:
        config_lines = f.readlines()
        for line in config_lines:
            if not line.startswith("#") and line != '\n':
                m = re.search('CONFIG_(\w+)=([\w"-/]+)', line)
                var_name = m.group(1)
                var_val = m.group(2)
                res[var_name] = var_val
    return res

# %% [markdown]
# # Extracting solutions

# %%
# Extract the SOLU_SIZE solutions
fla = CNF(DIMACS_FLA)
models = []
with Solver(bootstrap_with=fla.clauses) as s:
    s.solve()
    for no, k in enumerate(s.enum_models(), 1):
        if no > SOLU_SIZE:
            break
        models.append(k)

# %%
# Erase every variables that are not "real" features
config_models = list(map(lambda x: {variables[k] for k in x if k > 0 and k in variables}, models))

# %%
# Get rid of redundant solutions
lon = len(config_models)
res = list()
current = 0
in_list = True
while(in_list):
    res.append(config_models[current])
    for k in range(current + 1, lon):
        if config_models[current] != config_models[k]:
            current = k
            break
        if k == lon - 1:
            in_list = False

# %%
potential_configurations = res
len(potential_configurations)
# Out:
# 108

# %% [markdown]
# # Config Generation

# %%
# Dictionary {option : [possible_values+]}
feature = dict()
with open(DIMACS_FLA, 'r') as f:
    dimacs_lines = f.readlines()
    for line in dimacs_lines:
        if line.startswith("c") and '=' in line:
            m = re.search('(c) (\d+) (\w+)=([\w"-/]*)', line)
#             print(m.group(3), m.group(4))
            if m.group(4) != 'nonempty' and m.group(4) != 'n':
                if m.group(3) in feature:
                    feature[m.group(3)].append(m.group(4))
                else:
                    feature[m.group(3)] = [m.group(4)]

# %%
import random

# Write .config content using the solution and 
# pick a random value in the list as real value in
# the configuration
def create_file_content(res):
    df_options = pd.read_csv('examples/alloptions-x86.4.14.152.csv')
    # file content
    file = ""
    for elt in res:
        if "CHOICE_" in elt:
            continue
        kconfig_type = search_kconfig_type(elt, df_options)
        if kconfig_type == 'BOOL':
    #         print("CONFIG_{}=y".format(elt))
            file += "CONFIG_{}=y\n".format(elt)
        elif kconfig_type == 'TRISTATE':
            file += "CONFIG_{}=y\n".format(elt)
        elif kconfig_type == "STRING":
            if elt == "IMA_DEFAULT_HASH":
                found = False
                for k in res:
                    if "IMA_DEFAULT_HASH_" in k and k != "IMA_DEFAULT_HASH":
                        file += 'CONFIG_{}="{}"\n'.format(elt, k[17:].lower())
                        found = True
                if not found:
                    file += 'CONFIG_{}=""\n'.format(elt)
            else:
                file += 'CONFIG_{}="{}"\n'.format(elt, random.choice(feature[elt]))
        elif kconfig_type == "INT":
            file += "CONFIG_{}={}\n".format(elt, random.choice(feature[elt]))
        elif kconfig_type == "HEX":
            file += "CONFIG_{}={}\n".format(elt, random.choice(feature[elt]))
    return file

# %%
# Create .config (experimentation)
def create_config_xp(res):
    file_content = create_file_content(res)
    with open('../linux-4.14.152/.config', 'w') as stream:
        stream.write("# EXPERIMENTATION\n##################\n")
        stream.write(file_content)

# %%
# potential_configurations = potential_configurations[:3]

# %%
diff_opt_occ = dict()
for solu in potential_configurations:
    create_config_xp(solu)
    os.system("make olddefconfig -C {}".format(CONFIG_DIR))
    new_config = get_dict("{}/.config".format(CONFIG_DIR))
    # diff
    if len(new_config) > len(solu):
        diff = set(new_config) - solu
        for feat in diff:
            if feat in diff_opt_occ:
                diff_opt_occ[feat] += 1
            else:
                diff_opt_occ[feat] = 1

# %%
# Saving data
file_content = "option;occurence\n"
for option in diff_opt_occ.keys():
    file_content += "{};{}\n".format(option, diff_opt_occ[option])
with open("examples/diff_occ.csv", "w") as stream:
    stream.write(file_content)

# %%
diff_opt_occ
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-10-fb090e948ba9> in <module>
# ----> 1 diff_opt_occ
#
# NameError: name 'diff_opt_occ' is not defined

# %%
for k in diff_opt_occ.keys():
    if diff_opt_occ[k] != 108:
        print(k)
# Out:
# BOUNCE
# CAN_CALC_BITTIMING
# SQUASHFS_ZLIB
# SCSI_SAS_HOST_SMP
# OCFS2_FS_STATS
# CAPI_TRACE
# XEN_SCRUB_PAGES
# COMMON_CLK_XGENE
# MSDOS_PARTITION
# FB_ATY_BACKLIGHT

# %%
len(diff_opt_occ)
# Out:
# 414

# %% [markdown]
# # Playground

# %%
# Read file of impossible values
def read_imp_val_csv(file):
    df = pd.read_csv(file)
    df_dict = df.to_dict()
    res = dict()
    for k, v in df_dict['option'].items():
        imp = map(lambda x: x.replace("'", ''), 
                  df_dict['impossible_value'][k][1:-1].split()) 
        res[v] = set(imp)
    return res
impossible_values = read_imp_val_csv('examples/impossible.csv')

# %%
# Read file of diff and occurences
df = pd.read_csv("examples/diff_occ.csv", sep=";")
diff_opt_occ = df.set_index('option')['occurence'].to_dict()

# %%
diff_opt_occ
# Out:
# {'USB_PCI': 108,
#  'IR_MCE_KBD_DECODER': 108,
#  'TRACEPOINTS': 108,
#  'HW_RANDOM_MTK': 108,
#  'FRAMEBUFFER_CONSOLE_DETECT_PRIMARY': 108,
#  'WLAN_VENDOR_TI': 108,
#  'SND_VERBOSE_PROCFS': 108,
#  'HID_ITE': 108,
#  'LDISC_AUTOLOAD': 108,
#  'PREVENT_FIRMWARE_BUILD': 108,
#  'AIC79XX_REG_PRETTY_PRINT': 108,
#  'RT2800PCI_RT53XX': 108,
#  'X86_MCE_THRESHOLD': 108,
#  'DVB_NET': 108,
#  'CAN_BCM': 108,
#  'IR_XMP_DECODER': 108,
#  'SCSI_PROC_FS': 108,
#  'RSI_USB': 108,
#  'HID_PICOLCD_LCD': 108,
#  'SECTION_MISMATCH_WARN_ONLY': 108,
#  'FB_RADEON_I2C': 108,
#  'ACPI_SLEEP': 108,
#  'HW_RANDOM': 108,
#  'KVM_GUEST': 108,
#  'VIDEO_GO7007_LOADER': 108,
#  'COMPAT_BRK': 108,
#  'HID_BELKIN': 108,
#  'NET_VENDOR_VIA': 108,
#  'RT2800USB_RT33XX': 108,
#  'NET_VENDOR_SYNOPSYS': 108,
#  'IDEPCI_PCIBUS_ORDER': 108,
#  'SH_DMAE_BASE': 108,
#  'LOGO_LINUX_CLUT224': 108,
#  'UBIFS_FS_SECURITY': 108,
#  'CRYPTO_LZO': 108,
#  'CPU_IDLE': 108,
#  'HID_KENSINGTON': 108,
#  'HID_A4TECH': 108,
#  'INET6_XFRM_MODE_TRANSPORT': 108,
#  'CONTEXT_TRACKING_FORCE': 108,
#  'HISI_THERMAL': 108,
#  'MOUSE_PS2_ALPS': 108,
#  'HVC_XEN_FRONTEND': 108,
#  'USB_BELKIN': 108,
#  'IGB_DCA': 108,
#  'THERMAL_GOV_USER_SPACE': 108,
#  'XEN_DOM0': 108,
#  'BLK_DEBUG_FS': 108,
#  'NF_NAT_PROTO_DCCP': 108,
#  'BCM_VIDEOCORE': 108,
#  'I2C_HELPER_AUTO': 108,
#  'TOUCHSCREEN_WM9705': 108,
#  'BINARY_PRINTF': 108,
#  'MOUSE_PS2': 108,
#  'MTK_THERMAL': 108,
#  'USB_EHCI_TT_NEWSCHED': 108,
#  'NET_VENDOR_ALACRITECH': 108,
#  'USB_GSPCA': 108,
#  'CARDBUS': 108,
#  'GLOB': 108,
#  'GIGASET_CAPI': 108,
#  'NET_VENDOR_NATSEMI': 108,
#  'NETFILTER_INGRESS': 108,
#  'CRYPTO_DEFLATE': 108,
#  'BCMA_DRIVER_PCI': 108,
#  'VIDEO_PVRUSB2_SYSFS': 108,
#  'NET_PTP_CLASSIFY': 108,
#  'BRANCH_PROFILE_NONE': 108,
#  'NET_VENDOR_TEHUTI': 108,
#  'INET_TUNNEL': 108,
#  'USB_VIDEO_CLASS_INPUT_EVDEV': 108,
#  'DEVPORT': 108,
#  'IR_RC5_DECODER': 108,
#  'UPROBE_EVENTS': 108,
#  'NETFILTER_XT_MATCH_L2TP': 108,
#  'NET_VENDOR_XIRCOM': 108,
#  'HW_RANDOM_MESON': 108,
#  'SCSI_SYM53C8XX_MMIO': 108,
#  'THINKPAD_ACPI_ALSA_SUPPORT': 108,
#  'USB_DEFAULT_PERSIST': 108,
#  'PCMCIA_LOAD_CIS': 108,
#  'X86_THERMAL_VECTOR': 108,
#  'BLK_DEV': 108,
#  'CAPI_TRACE': 101,
#  'COMMON_CLK_XGENE': 107,
#  'IR_JVC_DECODER': 108,
#  'HID_MICROSOFT': 108,
#  'BT_HS': 108,
#  'VIDEO_CX88_VP3054': 108,
#  'SIRFSOC_WATCHDOG': 108,
#  'MOUSE_PS2_SYNAPTICS_SMBUS': 108,
#  'OCFS2_DEBUG_MASKLOG': 108,
#  'BOUNCE': 66,
#  'THERMAL_HWMON': 108,
#  'SECCOMP': 108,
#  'PM_GENERIC_DOMAINS_OF': 108,
#  'TIGON3_HWMON': 108,
#  'XEN_SCRUB_PAGES': 83,
#  'NET_VENDOR_8390': 108,
#  'MOUSE_PS2_SYNAPTICS': 108,
#  'RANDOMIZE_BASE': 108,
#  'SERIO_LIBPS2': 108,
#  'WLAN_VENDOR_QUANTENNA': 108,
#  'UPROBES': 108,
#  'THERMAL_GOV_STEP_WISE': 108,
#  'WLAN_VENDOR_ADMTEK': 108,
#  'XEN_PCIDEV_BACKEND': 108,
#  'HID_CHERRY': 108,
#  'XENFS': 108,
#  'PROC_VMCORE': 108,
#  'PID_NS': 108,
#  'RC_MAP': 108,
#  'X86_MCE_AMD': 108,
#  'BT_DEBUGFS': 108,
#  'XEN_PVHVM': 108,
#  'HVC_DRIVER': 108,
#  'B43_PHY_HT': 108,
#  'X86_NEED_RELOCS': 108,
#  'GENERIC_PINMUX_FUNCTIONS': 108,
#  'MLXSW_SWITCHIB': 108,
#  'NET_VENDOR_HISILICON': 108,
#  'EVENT_TRACING': 108,
#  'TRACING': 108,
#  'SERIO_I8042': 108,
#  'NET_VENDOR_MICREL': 108,
#  'IXGBE_HWMON': 108,
#  'SLAB_MERGE_DEFAULT': 108,
#  'TCP_CONG_BIC': 108,
#  'HW_RANDOM_INTEL': 108,
#  'MTD_OF_PARTS': 108,
#  'NF_CONNTRACK_PROCFS': 108,
#  'PROBE_EVENTS': 108,
#  'SND_CS46XX_NEW_DSP': 108,
#  'NET_VENDOR_AQUANTIA': 108,
#  'THERMAL_WRITABLE_TRIPS': 108,
#  'NET_VENDOR_EXAR': 108,
#  'BNXT_FLOWER_OFFLOAD': 108,
#  'SPARSEMEM_VMEMMAP': 108,
#  'FRAMEBUFFER_CONSOLE': 108,
#  'NF_CT_PROTO_UDPLITE': 108,
#  'MTD_CFI_I1': 108,
#  'PERF_EVENTS_INTEL_UNCORE': 108,
#  'HVC_IRQ': 108,
#  'SFC_MTD': 108,
#  'NETWORK_FILESYSTEMS': 108,
#  'NET_CADENCE': 108,
#  'XEN_BACKEND': 108,
#  'NET_VENDOR_MARVELL': 108,
#  'NET_VENDOR_MICROCHIP': 108,
#  'THINKPAD_ACPI_VIDEO': 108,
#  'RETPOLINE': 108,
#  'NET_VENDOR_CAVIUM': 108,
#  'MLXSW_SPECTRUM_DCB': 108,
#  'ACPI_AC': 108,
#  'HW_RANDOM_AMD': 108,
#  'PNP_DEBUG_MESSAGES': 108,
#  'NET_VENDOR_STMICRO': 108,
#  'NET_VENDOR_EMULEX': 108,
#  'FTRACE': 108,
#  'XEN_GRANT_DEV_ALLOC': 108,
#  'CAN_GW': 108,
#  'MLXSW_SWITCHX2': 108,
#  'ACPI_I2C_OPREGION': 108,
#  'IPV6_SIT': 108,
#  'WIL6210_TRACING': 108,
#  'MTD_CFI_I2': 108,
#  'PM_GENERIC_DOMAINS': 108,
#  'IDE_PROC_FS': 108,
#  'HVC_XEN': 108,
#  'SFC_MCDI_MON': 108,
#  'SCHED_DEBUG': 108,
#  'MICROCODE_INTEL': 108,
#  'RT2800PCI_RT35XX': 108,
#  'RT2800PCI_RT3290': 108,
#  'MOUSE_PS2_TRACKPOINT': 108,
#  'NET_VENDOR_AMAZON': 108,
#  'NET_VENDOR_QUALCOMM': 108,
#  'ARCH_USES_HIGH_VMA_FLAGS': 108,
#  'LCD_CLASS_DEVICE': 108,
#  'UBIFS_FS_ZLIB': 108,
#  'KEYBOARD_ATKBD': 108,
#  'NET_VENDOR_RENESAS': 108,
#  'TOUCHSCREEN_WM9713': 108,
#  'RC_DECODERS': 108,
#  'NET_VENDOR_ROCKER': 108,
#  'BINFMT_SCRIPT': 108,
#  'RENESAS_DMA': 108,
#  'PERF_EVENTS_INTEL_CSTATE': 108,
#  'NET_INGRESS': 108,
#  'MLXSW_CORE_THERMAL': 108,
#  'INFINIBAND_ADDR_TRANS_CONFIGFS': 108,
#  'HID_APPLE': 108,
#  'WLAN_VENDOR_ATMEL': 108,
#  'SQUASHFS_ZLIB': 69,
#  'USB_OHCI_HCD_PCI': 108,
#  'PAGE_TABLE_ISOLATION': 108,
#  'IR_SHARP_DECODER': 108,
#  'NET_VENDOR_RDC': 108,
#  'NF_NAT_PROTO_UDPLITE': 108,
#  'ACPI_PROCESSOR': 108,
#  'USB_HID': 108,
#  'X86_VERBOSE_BOOTUP': 108,
#  'WLAN_VENDOR_ZYDAS': 108,
#  'ELFCORE': 108,
#  'COMPACTION': 108,
#  'NFP_APP_FLOWER': 108,
#  'PERF_EVENTS_INTEL_RAPL': 108,
#  'PM_GENERIC_DOMAINS_SLEEP': 108,
#  'CROSS_MEMORY_ATTACH': 108,
#  'LZO_DECOMPRESS': 108,
#  'XEN_BLKDEV_FRONTEND': 108,
#  'ACPI_BATTERY': 108,
#  'WLAN_VENDOR_ST': 108,
#  'NF_NAT_PROTO_SCTP': 108,
#  'GENERIC_PINCTRL_GROUPS': 108,
#  'SMS_SIANO_RC': 108,
#  'ACPI_CPU_FREQ_PSS': 108,
#  'MTD_MAP_BANK_WIDTH_2': 108,
#  'INPUT_KEYBOARD': 108,
#  'CPU_IDLE_GOV_LADDER': 108,
#  'SERIAL_SC16IS7XX_I2C': 108,
#  'ACPI_FAN': 108,
#  'WATCHDOG_HANDLE_BOOT_ENABLED': 108,
#  'MLXSW_CORE_HWMON': 108,
#  'ACPI_PROCESSOR_IDLE': 108,
#  'DVB_AV7110_OSD': 108,
#  'MICROCODE_OLD_INTERFACE': 108,
#  'XEN_SYS_HYPERVISOR': 108,
#  'NET_VENDOR_ADAPTEC': 108,
#  'BNXT_SRIOV': 108,
#  'INFINIBAND_ADDR_TRANS': 108,
#  'RELOCATABLE': 108,
#  'PRINT_QUOTA_WARNING': 108,
#  'NET_VENDOR_AGERE': 108,
#  'LOGO_LINUX_MONO': 108,
#  'RT2800USB_RT35XX': 108,
#  'BINFMT_ELF': 108,
#  'X86_DEBUG_FPU': 108,
#  'CORE_DUMP_DEFAULT_ELF_HEADERS': 108,
#  'MTRR_SANITIZER': 108,
#  'HW_RANDOM_VIA': 108,
#  'ACPI_REV_OVERRIDE_POSSIBLE': 108,
#  'NET_VENDOR_TI': 108,
#  'X86_INTEL_MEMORY_PROTECTION_KEYS': 108,
#  'WIL6210_DEBUGFS': 108,
#  'MTD_MAP_BANK_WIDTH_1': 108,
#  'FONT_8x8': 108,
#  'BATMAN_ADV_BLA': 108,
#  'TCP_CONG_HTCP': 108,
#  'HID_LOGITECH': 108,
#  'PTP_1588_CLOCK_DTE': 108,
#  'DETECT_HUNG_TASK': 108,
#  'PINCTRL_INGENIC': 108,
#  'HID_EZKEY': 108,
#  'REALTEK_AUTOPM': 108,
#  'FB_MB862XX_I2C': 108,
#  'LEGACY_PTYS': 108,
#  'NET_VENDOR_SAMSUNG': 108,
#  'HT_IRQ': 108,
#  'CRYPTO_MANAGER_DISABLE_TESTS': 108,
#  'THINKPAD_ACPI_HOTKEY_POLL': 108,
#  'TRACE_CLOCK': 108,
#  'NET_VENDOR_OKI': 108,
#  'MOUSE_PS2_LIFEBOOK': 108,
#  'MOUSE_PS2_SMBUS': 108,
#  'TOUCHSCREEN_WM9712': 108,
#  'OCFS2_FS_O2CB': 108,
#  'ARCH_HAS_PKEYS': 108,
#  'NET_VENDOR_REALTEK': 108,
#  'XEN_PCIDEV_FRONTEND': 108,
#  'XEN_512GB': 108,
#  'DMIID': 108,
#  'EXT4_USE_FOR_EXT2': 108,
#  'BT_BREDR': 108,
#  'IXGBE_DCA': 108,
#  'MOUSE_PS2_LOGIPS2PP': 108,
#  'XEN_NETDEV_FRONTEND': 108,
#  'IGB_HWMON': 108,
#  'IDE_GD_ATA': 108,
#  'SYS_HYPERVISOR': 108,
#  'BCMA_HOST_PCI': 108,
#  'VIRTUALIZATION': 108,
#  'NET_VENDOR_SEEQ': 108,
#  'NET_VENDOR_SUN': 108,
#  'CONTEXT_SWITCH_TRACER': 108,
#  'NET_VENDOR_BROCADE': 108,
#  'MOUSE_PS2_BYD': 108,
#  'NET_VENDOR_FUJITSU': 108,
#  'MLXSW_MINIMAL': 108,
#  'INTEL_SCU_IPC_UTIL': 108,
#  'DEVMEM': 108,
#  'XEN_SYMS': 108,
#  'NET_NS': 108,
#  'USB_XHCI_PCI': 108,
#  'KXSD9_I2C': 108,
#  'IOSCHED_DEADLINE': 108,
#  'CAN_RAW': 108,
#  'B43_HWRNG': 108,
#  'UBIFS_FS_LZO': 108,
#  'DRM_KMS_FB_HELPER': 108,
#  'KXSD9_SPI': 108,
#  'MOUSE_PS2_FOCALTECH': 108,
#  'PTP_1588_CLOCK': 108,
#  'IDE_GD': 108,
#  'NET_VENDOR_HP': 108,
#  'RSI_DEBUGFS': 108,
#  'INPUT_LEDS': 108,
#  'PTP_1588_CLOCK_KVM': 108,
#  'MANDATORY_FILE_LOCKING': 108,
#  'DM_CACHE_SMQ': 108,
#  'E1000E_HWTS': 108,
#  'VIDEO_EM28XX_RC': 108,
#  'NET_VENDOR_SIS': 108,
#  'THERMAL_OF': 108,
#  'NET_VENDOR_ATHEROS': 108,
#  'VT_HW_CONSOLE_BINDING': 108,
#  'PPS': 108,
#  'HYPERV_STORAGE': 108,
#  'I2C_COMPAT': 108,
#  'USB_ARMLINUX': 108,
#  'SECCOMP_FILTER': 108,
#  'WLAN_VENDOR_MARVELL': 108,
#  'MOUSE_PS2_CYPRESS': 108,
#  'CAN_CALC_BITTIMING': 31,
#  'RTLWIFI_DEBUG': 108,
#  'ENABLE_WARN_DEPRECATED': 108,
#  'BNX2X_SRIOV': 108,
#  'THERMAL_DEFAULT_GOV_STEP_WISE': 108,
#  'RING_BUFFER': 108,
#  'WIL6210_ISR_COR': 108,
#  'NET_VENDOR_I825XX': 108,
#  'AIC79XX_DEBUG_ENABLE': 108,
#  'DRM_FBDEV_EMULATION': 108,
#  'AIC94XX_DEBUG': 108,
#  'XEN_AUTO_XLATE': 108,
#  'MQ_IOSCHED_DEADLINE': 108,
#  'SND_SUPPORT_OLD_API': 108,
#  'NET_VENDOR_SILAN': 108,
#  'INET_XFRM_MODE_BEET': 108,
#  'SWAP': 108,
#  'NET_VENDOR_CISCO': 108,
#  'RSI_SDIO': 108,
#  'IR_RC6_DECODER': 108,
#  'HID_CYPRESS': 108,
#  'LZO_COMPRESS': 108,
#  'NET_VENDOR_NVIDIA': 108,
#  'NET_VENDOR_DLINK': 108,
#  'XEN_DEV_EVTCHN': 108,
#  'UTS_NS': 108,
#  'DNOTIFY': 108,
#  'INOTIFY_USER': 108,
#  'ENABLE_MUST_CHECK': 108,
#  'BT_LE': 108,
#  'SFC_MCDI_LOGGING': 108,
#  'MSDOS_PARTITION': 107,
#  'NET_PACKET_ENGINE': 108,
#  'MQ_IOSCHED_KYBER': 108,
#  'HW_RANDOM_CAVIUM': 108,
#  'ZLIB_DEFLATE': 108,
#  'USB_EHCI_PCI': 108,
#  'SCHED_OMIT_FRAME_POINTER': 108,
#  'RT2800PCI_RT33XX': 108,
#  'SERIAL_SC16IS7XX_CORE': 108,
#  'XEN_COMPAT_XENFS': 108,
#  'IR_NEC_DECODER': 108,
#  'EFI_PARTITION': 108,
#  'NET_VENDOR_EZCHIP': 108,
#  'LOGO_LINUX_VGA16': 108,
#  'X86_MPPARSE': 108,
#  'ACPI_BUTTON': 108,
#  'WLAN_VENDOR_MEDIATEK': 108,
#  'UNUSED_SYMBOLS': 108,
#  'VIDEO_SAA7134_RC': 108,
#  'TRACING_EVENTS_GPIO': 108,
#  'UEVENT_HELPER': 108,
#  'MOUSE_ELAN_I2C_I2C': 108,
#  'SUSPEND': 108,
#  'RANDOMIZE_MEMORY': 108,
#  'MICROCODE': 108,
#  'IR_SONY_DECODER': 108,
#  'NET_VENDOR_HUAWEI': 108,
#  'B43_PHY_N': 108,
#  'HID_CHICONY': 108,
#  'NOP_TRACER': 108,
#  'TCP_CONG_WESTWOOD': 108,
#  'LWTUNNEL_BPF': 108,
#  'MYRI10GE_DCA': 108,
#  'NF_CT_PROTO_SCTP': 108,
#  'NET_VENDOR_ARC': 108,
#  'IR_SANYO_DECODER': 108,
#  'PWRSEQ_SIMPLE': 108,
#  'VIDEO_CX88_ENABLE_VP3054': 108,
#  'X86_MCE_INTEL': 108,
#  'SFC_SRIOV': 108,
#  'SCSI_SAS_HOST_SMP': 40,
#  'X86_PKG_TEMP_THERMAL': 108,
#  'OCFS2_FS_STATS': 33,
#  'CFG80211_DEFAULT_PS': 108,
#  'IPV6_NDISC_NODETYPE': 108,
#  'TCP_CONG_CUBIC': 108,
#  'INET_XFRM_MODE_TRANSPORT': 108,
#  'SUSPEND_FREEZER': 108,
#  'PWRSEQ_EMMC': 108,
#  'THERMAL': 108,
#  'FIRMWARE_IN_KERNEL': 108,
#  'ACPI_THERMAL': 108,
#  'INET6_XFRM_MODE_BEET': 108,
#  'NET_VENDOR_FREESCALE': 108,
#  'CRYPTO_ECHAINIV': 108,
#  'HID_MONTEREY': 108,
#  'NET_VENDOR_ALTEON': 108,
#  'NF_CT_PROTO_DCCP': 108,
#  'ARM_SCPI_POWER_DOMAIN': 108,
#  'FB_ATY_BACKLIGHT': 41}

# %%
# count core features from diff dict
core_f = 0
hasnt_iv = 0
for opt in diff_opt_occ:
    if opt in impossible_values :
        if 'n' in impossible_values[opt]:
            core_f += 1
    else:
        hasnt_iv += 1
print("{}/{} have not impossible values\n{}/{} of core features".format(hasnt_iv, len(diff_opt_occ),
                                                                        core_f, len(diff_opt_occ)))
# Out:
# 414/414 have not impossible values
# 0/414 of core features

# %%
len(config_models[0])
# Out:
# 2182

# %%
nb = 0
for k in diff_opt_occ.keys():
    if diff_opt_occ[k] == 108:
        nb += 1

# %%
nb
# Out:
# 404

# %%
diff_opt_occ['THERMAL_HWMON'] == diff_opt_occ['THERMAL']
# Out:
# True

# %%
diff_opt_occ2 = dict()
for solu in potential_configurations[:4]:
    create_config_xp(solu)
    os.system("make oldconfig -C {}".format(CONFIG_DIR))
    new_config = get_dict("{}/.config".format(CONFIG_DIR))
    # diff
    if len(new_config) > len(solu):
        diff = set(new_config) - solu
        for feat in diff:
            if feat in diff_opt_occ2:
                diff_opt_occ2[feat] += 1
            else:
                diff_opt_occ2[feat] = 1

# %%
diff_opt_occ2
# Out:
# {'USB_PCI': 4,
#  'IR_MCE_KBD_DECODER': 4,
#  'TRACEPOINTS': 4,
#  'HW_RANDOM_MTK': 4,
#  'FRAMEBUFFER_CONSOLE_DETECT_PRIMARY': 4,
#  'WLAN_VENDOR_TI': 4,
#  'SND_VERBOSE_PROCFS': 4,
#  'HID_ITE': 4,
#  'LDISC_AUTOLOAD': 4,
#  'PREVENT_FIRMWARE_BUILD': 4,
#  'AIC79XX_REG_PRETTY_PRINT': 4,
#  'RT2800PCI_RT53XX': 4,
#  'X86_MCE_THRESHOLD': 4,
#  'DVB_NET': 4,
#  'CAN_BCM': 4,
#  'IR_XMP_DECODER': 4,
#  'SCSI_PROC_FS': 4,
#  'RSI_USB': 4,
#  'HID_PICOLCD_LCD': 4,
#  'SECTION_MISMATCH_WARN_ONLY': 4,
#  'FB_RADEON_I2C': 4,
#  'ACPI_SLEEP': 4,
#  'HW_RANDOM': 4,
#  'KVM_GUEST': 4,
#  'VIDEO_GO7007_LOADER': 4,
#  'COMPAT_BRK': 4,
#  'HID_BELKIN': 4,
#  'NET_VENDOR_VIA': 4,
#  'RT2800USB_RT33XX': 4,
#  'NET_VENDOR_SYNOPSYS': 4,
#  'IDEPCI_PCIBUS_ORDER': 4,
#  'SH_DMAE_BASE': 4,
#  'LOGO_LINUX_CLUT224': 4,
#  'UBIFS_FS_SECURITY': 4,
#  'CRYPTO_LZO': 4,
#  'CPU_IDLE': 4,
#  'HID_KENSINGTON': 4,
#  'HID_A4TECH': 4,
#  'INET6_XFRM_MODE_TRANSPORT': 4,
#  'CONTEXT_TRACKING_FORCE': 4,
#  'HISI_THERMAL': 4,
#  'MOUSE_PS2_ALPS': 4,
#  'HVC_XEN_FRONTEND': 4,
#  'USB_BELKIN': 4,
#  'IGB_DCA': 4,
#  'THERMAL_GOV_USER_SPACE': 4,
#  'XEN_DOM0': 4,
#  'BLK_DEBUG_FS': 4,
#  'NF_NAT_PROTO_DCCP': 4,
#  'BCM_VIDEOCORE': 4,
#  'I2C_HELPER_AUTO': 4,
#  'TOUCHSCREEN_WM9705': 4,
#  'BINARY_PRINTF': 4,
#  'MOUSE_PS2': 4,
#  'MTK_THERMAL': 4,
#  'USB_EHCI_TT_NEWSCHED': 4,
#  'NET_VENDOR_ALACRITECH': 4,
#  'USB_GSPCA': 4,
#  'CARDBUS': 4,
#  'GLOB': 4,
#  'GIGASET_CAPI': 4,
#  'NET_VENDOR_NATSEMI': 4,
#  'NETFILTER_INGRESS': 4,
#  'CRYPTO_DEFLATE': 4,
#  'BCMA_DRIVER_PCI': 4,
#  'VIDEO_PVRUSB2_SYSFS': 4,
#  'NET_PTP_CLASSIFY': 4,
#  'BRANCH_PROFILE_NONE': 4,
#  'NET_VENDOR_TEHUTI': 4,
#  'INET_TUNNEL': 4,
#  'USB_VIDEO_CLASS_INPUT_EVDEV': 4,
#  'DEVPORT': 4,
#  'IR_RC5_DECODER': 4,
#  'UPROBE_EVENTS': 4,
#  'NETFILTER_XT_MATCH_L2TP': 4,
#  'NET_VENDOR_XIRCOM': 4,
#  'HW_RANDOM_MESON': 4,
#  'SCSI_SYM53C8XX_MMIO': 4,
#  'THINKPAD_ACPI_ALSA_SUPPORT': 4,
#  'USB_DEFAULT_PERSIST': 4,
#  'PCMCIA_LOAD_CIS': 4,
#  'X86_THERMAL_VECTOR': 4,
#  'BLK_DEV': 4,
#  'CAPI_TRACE': 4,
#  'COMMON_CLK_XGENE': 4,
#  'IR_JVC_DECODER': 4,
#  'HID_MICROSOFT': 4,
#  'BT_HS': 4,
#  'VIDEO_CX88_VP3054': 4,
#  'SIRFSOC_WATCHDOG': 4,
#  'MOUSE_PS2_SYNAPTICS_SMBUS': 4,
#  'OCFS2_DEBUG_MASKLOG': 4,
#  'BOUNCE': 4,
#  'THERMAL_HWMON': 4,
#  'SECCOMP': 4,
#  'PM_GENERIC_DOMAINS_OF': 4,
#  'TIGON3_HWMON': 4,
#  'XEN_SCRUB_PAGES': 4,
#  'NET_VENDOR_8390': 4,
#  'MOUSE_PS2_SYNAPTICS': 4,
#  'RANDOMIZE_BASE': 4,
#  'SERIO_LIBPS2': 4,
#  'WLAN_VENDOR_QUANTENNA': 4,
#  'UPROBES': 4,
#  'THERMAL_GOV_STEP_WISE': 4,
#  'WLAN_VENDOR_ADMTEK': 4,
#  'XEN_PCIDEV_BACKEND': 4,
#  'HID_CHERRY': 4,
#  'XENFS': 4,
#  'PROC_VMCORE': 4,
#  'PID_NS': 4,
#  'RC_MAP': 4,
#  'X86_MCE_AMD': 4,
#  'BT_DEBUGFS': 4,
#  'XEN_PVHVM': 4,
#  'HVC_DRIVER': 4,
#  'B43_PHY_HT': 4,
#  'X86_NEED_RELOCS': 4,
#  'GENERIC_PINMUX_FUNCTIONS': 4,
#  'MLXSW_SWITCHIB': 4,
#  'NET_VENDOR_HISILICON': 4,
#  'EVENT_TRACING': 4,
#  'TRACING': 4,
#  'SERIO_I8042': 4,
#  'NET_VENDOR_MICREL': 4,
#  'IXGBE_HWMON': 4,
#  'SLAB_MERGE_DEFAULT': 4,
#  'TCP_CONG_BIC': 4,
#  'HW_RANDOM_INTEL': 4,
#  'MTD_OF_PARTS': 4,
#  'NF_CONNTRACK_PROCFS': 4,
#  'PROBE_EVENTS': 4,
#  'SND_CS46XX_NEW_DSP': 4,
#  'NET_VENDOR_AQUANTIA': 4,
#  'THERMAL_WRITABLE_TRIPS': 4,
#  'NET_VENDOR_EXAR': 4,
#  'BNXT_FLOWER_OFFLOAD': 4,
#  'SPARSEMEM_VMEMMAP': 4,
#  'FRAMEBUFFER_CONSOLE': 4,
#  'NF_CT_PROTO_UDPLITE': 4,
#  'MTD_CFI_I1': 4,
#  'PERF_EVENTS_INTEL_UNCORE': 4,
#  'HVC_IRQ': 4,
#  'SFC_MTD': 4,
#  'NETWORK_FILESYSTEMS': 4,
#  'NET_CADENCE': 4,
#  'XEN_BACKEND': 4,
#  'NET_VENDOR_MARVELL': 4,
#  'NET_VENDOR_MICROCHIP': 4,
#  'THINKPAD_ACPI_VIDEO': 4,
#  'RETPOLINE': 4,
#  'NET_VENDOR_CAVIUM': 4,
#  'MLXSW_SPECTRUM_DCB': 4,
#  'ACPI_AC': 4,
#  'HW_RANDOM_AMD': 4,
#  'PNP_DEBUG_MESSAGES': 4,
#  'NET_VENDOR_STMICRO': 4,
#  'NET_VENDOR_EMULEX': 4,
#  'FTRACE': 4,
#  'XEN_GRANT_DEV_ALLOC': 4,
#  'CAN_GW': 4,
#  'MLXSW_SWITCHX2': 4,
#  'ACPI_I2C_OPREGION': 4,
#  'IPV6_SIT': 4,
#  'WIL6210_TRACING': 4,
#  'MTD_CFI_I2': 4,
#  'PM_GENERIC_DOMAINS': 4,
#  'IDE_PROC_FS': 4,
#  'HVC_XEN': 4,
#  'SFC_MCDI_MON': 4,
#  'SCHED_DEBUG': 4,
#  'MICROCODE_INTEL': 4,
#  'RT2800PCI_RT35XX': 4,
#  'RT2800PCI_RT3290': 4,
#  'MOUSE_PS2_TRACKPOINT': 4,
#  'NET_VENDOR_AMAZON': 4,
#  'NET_VENDOR_QUALCOMM': 4,
#  'ARCH_USES_HIGH_VMA_FLAGS': 4,
#  'LCD_CLASS_DEVICE': 4,
#  'UBIFS_FS_ZLIB': 4,
#  'KEYBOARD_ATKBD': 4,
#  'NET_VENDOR_RENESAS': 4,
#  'TOUCHSCREEN_WM9713': 4,
#  'RC_DECODERS': 4,
#  'NET_VENDOR_ROCKER': 4,
#  'BINFMT_SCRIPT': 4,
#  'RENESAS_DMA': 4,
#  'PERF_EVENTS_INTEL_CSTATE': 4,
#  'NET_INGRESS': 4,
#  'MLXSW_CORE_THERMAL': 4,
#  'INFINIBAND_ADDR_TRANS_CONFIGFS': 4,
#  'HID_APPLE': 4,
#  'WLAN_VENDOR_ATMEL': 4,
#  'SQUASHFS_ZLIB': 4,
#  'USB_OHCI_HCD_PCI': 4,
#  'PAGE_TABLE_ISOLATION': 4,
#  'IR_SHARP_DECODER': 4,
#  'NET_VENDOR_RDC': 4,
#  'NF_NAT_PROTO_UDPLITE': 4,
#  'ACPI_PROCESSOR': 4,
#  'USB_HID': 4,
#  'X86_VERBOSE_BOOTUP': 4,
#  'WLAN_VENDOR_ZYDAS': 4,
#  'ELFCORE': 4,
#  'COMPACTION': 4,
#  'NFP_APP_FLOWER': 4,
#  'PERF_EVENTS_INTEL_RAPL': 4,
#  'PM_GENERIC_DOMAINS_SLEEP': 4,
#  'CROSS_MEMORY_ATTACH': 4,
#  'LZO_DECOMPRESS': 4,
#  'XEN_BLKDEV_FRONTEND': 4,
#  'ACPI_BATTERY': 4,
#  'WLAN_VENDOR_ST': 4,
#  'NF_NAT_PROTO_SCTP': 4,
#  'GENERIC_PINCTRL_GROUPS': 4,
#  'SMS_SIANO_RC': 4,
#  'ACPI_CPU_FREQ_PSS': 4,
#  'MTD_MAP_BANK_WIDTH_2': 4,
#  'INPUT_KEYBOARD': 4,
#  'CPU_IDLE_GOV_LADDER': 4,
#  'SERIAL_SC16IS7XX_I2C': 4,
#  'ACPI_FAN': 4,
#  'WATCHDOG_HANDLE_BOOT_ENABLED': 4,
#  'MLXSW_CORE_HWMON': 4,
#  'ACPI_PROCESSOR_IDLE': 4,
#  'DVB_AV7110_OSD': 4,
#  'MICROCODE_OLD_INTERFACE': 4,
#  'XEN_SYS_HYPERVISOR': 4,
#  'NET_VENDOR_ADAPTEC': 4,
#  'BNXT_SRIOV': 4,
#  'INFINIBAND_ADDR_TRANS': 4,
#  'RELOCATABLE': 4,
#  'PRINT_QUOTA_WARNING': 4,
#  'NET_VENDOR_AGERE': 4,
#  'LOGO_LINUX_MONO': 4,
#  'RT2800USB_RT35XX': 4,
#  'BINFMT_ELF': 4,
#  'X86_DEBUG_FPU': 4,
#  'CORE_DUMP_DEFAULT_ELF_HEADERS': 4,
#  'MTRR_SANITIZER': 4,
#  'HW_RANDOM_VIA': 4,
#  'ACPI_REV_OVERRIDE_POSSIBLE': 4,
#  'NET_VENDOR_TI': 4,
#  'X86_INTEL_MEMORY_PROTECTION_KEYS': 4,
#  'WIL6210_DEBUGFS': 4,
#  'MTD_MAP_BANK_WIDTH_1': 4,
#  'FONT_8x8': 4,
#  'BATMAN_ADV_BLA': 4,
#  'TCP_CONG_HTCP': 4,
#  'HID_LOGITECH': 4,
#  'PTP_1588_CLOCK_DTE': 4,
#  'DETECT_HUNG_TASK': 4,
#  'PINCTRL_INGENIC': 4,
#  'HID_EZKEY': 4,
#  'REALTEK_AUTOPM': 4,
#  'FB_MB862XX_I2C': 4,
#  'LEGACY_PTYS': 4,
#  'NET_VENDOR_SAMSUNG': 4,
#  'HT_IRQ': 4,
#  'CRYPTO_MANAGER_DISABLE_TESTS': 4,
#  'THINKPAD_ACPI_HOTKEY_POLL': 4,
#  'TRACE_CLOCK': 4,
#  'NET_VENDOR_OKI': 4,
#  'MOUSE_PS2_LIFEBOOK': 4,
#  'MOUSE_PS2_SMBUS': 4,
#  'TOUCHSCREEN_WM9712': 4,
#  'OCFS2_FS_O2CB': 4,
#  'ARCH_HAS_PKEYS': 4,
#  'NET_VENDOR_REALTEK': 4,
#  'XEN_PCIDEV_FRONTEND': 4,
#  'XEN_512GB': 4,
#  'DMIID': 4,
#  'EXT4_USE_FOR_EXT2': 4,
#  'BT_BREDR': 4,
#  'IXGBE_DCA': 4,
#  'MOUSE_PS2_LOGIPS2PP': 4,
#  'XEN_NETDEV_FRONTEND': 4,
#  'IGB_HWMON': 4,
#  'IDE_GD_ATA': 4,
#  'SYS_HYPERVISOR': 4,
#  'BCMA_HOST_PCI': 4,
#  'VIRTUALIZATION': 4,
#  'NET_VENDOR_SEEQ': 4,
#  'NET_VENDOR_SUN': 4,
#  'CONTEXT_SWITCH_TRACER': 4,
#  'NET_VENDOR_BROCADE': 4,
#  'MOUSE_PS2_BYD': 4,
#  'NET_VENDOR_FUJITSU': 4,
#  'MLXSW_MINIMAL': 4,
#  'INTEL_SCU_IPC_UTIL': 4,
#  'DEVMEM': 4,
#  'XEN_SYMS': 4,
#  'NET_NS': 4,
#  'USB_XHCI_PCI': 4,
#  'KXSD9_I2C': 4,
#  'IOSCHED_DEADLINE': 4,
#  'CAN_RAW': 4,
#  'B43_HWRNG': 4,
#  'UBIFS_FS_LZO': 4,
#  'DRM_KMS_FB_HELPER': 4,
#  'KXSD9_SPI': 4,
#  'MOUSE_PS2_FOCALTECH': 4,
#  'PTP_1588_CLOCK': 4,
#  'IDE_GD': 4,
#  'NET_VENDOR_HP': 4,
#  'RSI_DEBUGFS': 4,
#  'INPUT_LEDS': 4,
#  'PTP_1588_CLOCK_KVM': 4,
#  'MANDATORY_FILE_LOCKING': 4,
#  'DM_CACHE_SMQ': 4,
#  'E1000E_HWTS': 4,
#  'VIDEO_EM28XX_RC': 4,
#  'NET_VENDOR_SIS': 4,
#  'THERMAL_OF': 4,
#  'NET_VENDOR_ATHEROS': 4,
#  'VT_HW_CONSOLE_BINDING': 4,
#  'PPS': 4,
#  'HYPERV_STORAGE': 4,
#  'I2C_COMPAT': 4,
#  'USB_ARMLINUX': 4,
#  'SECCOMP_FILTER': 4,
#  'WLAN_VENDOR_MARVELL': 4,
#  'MOUSE_PS2_CYPRESS': 4,
#  'CAN_CALC_BITTIMING': 4,
#  'RTLWIFI_DEBUG': 4,
#  'ENABLE_WARN_DEPRECATED': 4,
#  'BNX2X_SRIOV': 4,
#  'THERMAL_DEFAULT_GOV_STEP_WISE': 4,
#  'RING_BUFFER': 4,
#  'WIL6210_ISR_COR': 4,
#  'NET_VENDOR_I825XX': 4,
#  'AIC79XX_DEBUG_ENABLE': 4,
#  'DRM_FBDEV_EMULATION': 4,
#  'AIC94XX_DEBUG': 4,
#  'XEN_AUTO_XLATE': 4,
#  'MQ_IOSCHED_DEADLINE': 4,
#  'SND_SUPPORT_OLD_API': 4,
#  'NET_VENDOR_SILAN': 4,
#  'INET_XFRM_MODE_BEET': 4,
#  'SWAP': 4,
#  'NET_VENDOR_CISCO': 4,
#  'RSI_SDIO': 4,
#  'IR_RC6_DECODER': 4,
#  'HID_CYPRESS': 4,
#  'LZO_COMPRESS': 4,
#  'NET_VENDOR_NVIDIA': 4,
#  'NET_VENDOR_DLINK': 4,
#  'XEN_DEV_EVTCHN': 4,
#  'UTS_NS': 4,
#  'DNOTIFY': 4,
#  'INOTIFY_USER': 4,
#  'ENABLE_MUST_CHECK': 4,
#  'BT_LE': 4,
#  'SFC_MCDI_LOGGING': 4,
#  'MSDOS_PARTITION': 4,
#  'NET_PACKET_ENGINE': 4,
#  'MQ_IOSCHED_KYBER': 4,
#  'HW_RANDOM_CAVIUM': 4,
#  'ZLIB_DEFLATE': 4,
#  'USB_EHCI_PCI': 4,
#  'SCHED_OMIT_FRAME_POINTER': 4,
#  'RT2800PCI_RT33XX': 4,
#  'SERIAL_SC16IS7XX_CORE': 4,
#  'XEN_COMPAT_XENFS': 4,
#  'IR_NEC_DECODER': 4,
#  'EFI_PARTITION': 4,
#  'NET_VENDOR_EZCHIP': 4,
#  'LOGO_LINUX_VGA16': 4,
#  'X86_MPPARSE': 4,
#  'ACPI_BUTTON': 4,
#  'WLAN_VENDOR_MEDIATEK': 4,
#  'UNUSED_SYMBOLS': 4,
#  'VIDEO_SAA7134_RC': 4,
#  'TRACING_EVENTS_GPIO': 4,
#  'UEVENT_HELPER': 4,
#  'MOUSE_ELAN_I2C_I2C': 4,
#  'SUSPEND': 4,
#  'RANDOMIZE_MEMORY': 4,
#  'MICROCODE': 4,
#  'IR_SONY_DECODER': 4,
#  'NET_VENDOR_HUAWEI': 4,
#  'B43_PHY_N': 4,
#  'HID_CHICONY': 4,
#  'NOP_TRACER': 4,
#  'TCP_CONG_WESTWOOD': 4,
#  'LWTUNNEL_BPF': 4,
#  'MYRI10GE_DCA': 4,
#  'NF_CT_PROTO_SCTP': 4,
#  'NET_VENDOR_ARC': 4,
#  'IR_SANYO_DECODER': 4,
#  'PWRSEQ_SIMPLE': 4,
#  'VIDEO_CX88_ENABLE_VP3054': 4,
#  'X86_MCE_INTEL': 4,
#  'SFC_SRIOV': 4,
#  'SCSI_SAS_HOST_SMP': 4,
#  'X86_PKG_TEMP_THERMAL': 4,
#  'OCFS2_FS_STATS': 4,
#  'CFG80211_DEFAULT_PS': 4,
#  'IPV6_NDISC_NODETYPE': 4,
#  'TCP_CONG_CUBIC': 4,
#  'INET_XFRM_MODE_TRANSPORT': 4,
#  'SUSPEND_FREEZER': 4,
#  'PWRSEQ_EMMC': 4,
#  'THERMAL': 4,
#  'FIRMWARE_IN_KERNEL': 4,
#  'ACPI_THERMAL': 4,
#  'INET6_XFRM_MODE_BEET': 4,
#  'NET_VENDOR_FREESCALE': 4,
#  'CRYPTO_ECHAINIV': 4,
#  'HID_MONTEREY': 4,
#  'NET_VENDOR_ALTEON': 4,
#  'NF_CT_PROTO_DCCP': 4,
#  'ARM_SCPI_POWER_DOMAIN': 4}

# %%
test = dict()
solu = potential_configurations[10]
# ajout de THERMAL
solu.add("THERMAL_HWMON")
# Création de la config
create_config_xp(solu)
# Différence
os.system("make olddefconfig -C {}".format(CONFIG_DIR))
# new config file
new_config = get_dict("{}/.config".format(CONFIG_DIR))
# diff
diff = set(new_config) - solu
for feat in diff:
    if feat in test:
        test[feat] += 1
    else:
        test[feat] = 1

# %%
test
# Out:
# {'USB_PCI': 1,
#  'IR_MCE_KBD_DECODER': 1,
#  'TRACEPOINTS': 1,
#  'HW_RANDOM_MTK': 1,
#  'FRAMEBUFFER_CONSOLE_DETECT_PRIMARY': 1,
#  'WLAN_VENDOR_TI': 1,
#  'SND_VERBOSE_PROCFS': 1,
#  'HID_ITE': 1,
#  'LDISC_AUTOLOAD': 1,
#  'PREVENT_FIRMWARE_BUILD': 1,
#  'AIC79XX_REG_PRETTY_PRINT': 1,
#  'RT2800PCI_RT53XX': 1,
#  'X86_MCE_THRESHOLD': 1,
#  'DVB_NET': 1,
#  'CAN_BCM': 1,
#  'IR_XMP_DECODER': 1,
#  'SCSI_PROC_FS': 1,
#  'RSI_USB': 1,
#  'HID_PICOLCD_LCD': 1,
#  'SECTION_MISMATCH_WARN_ONLY': 1,
#  'FB_RADEON_I2C': 1,
#  'ACPI_SLEEP': 1,
#  'HW_RANDOM': 1,
#  'KVM_GUEST': 1,
#  'VIDEO_GO7007_LOADER': 1,
#  'COMPAT_BRK': 1,
#  'HID_BELKIN': 1,
#  'NET_VENDOR_VIA': 1,
#  'RT2800USB_RT33XX': 1,
#  'NET_VENDOR_SYNOPSYS': 1,
#  'IDEPCI_PCIBUS_ORDER': 1,
#  'SH_DMAE_BASE': 1,
#  'LOGO_LINUX_CLUT224': 1,
#  'UBIFS_FS_SECURITY': 1,
#  'CRYPTO_LZO': 1,
#  'CPU_IDLE': 1,
#  'HID_KENSINGTON': 1,
#  'HID_A4TECH': 1,
#  'INET6_XFRM_MODE_TRANSPORT': 1,
#  'CONTEXT_TRACKING_FORCE': 1,
#  'HISI_THERMAL': 1,
#  'MOUSE_PS2_ALPS': 1,
#  'HVC_XEN_FRONTEND': 1,
#  'USB_BELKIN': 1,
#  'IGB_DCA': 1,
#  'THERMAL_GOV_USER_SPACE': 1,
#  'XEN_DOM0': 1,
#  'BLK_DEBUG_FS': 1,
#  'NF_NAT_PROTO_DCCP': 1,
#  'BCM_VIDEOCORE': 1,
#  'I2C_HELPER_AUTO': 1,
#  'TOUCHSCREEN_WM9705': 1,
#  'BINARY_PRINTF': 1,
#  'MOUSE_PS2': 1,
#  'MTK_THERMAL': 1,
#  'USB_EHCI_TT_NEWSCHED': 1,
#  'NET_VENDOR_ALACRITECH': 1,
#  'USB_GSPCA': 1,
#  'CARDBUS': 1,
#  'GLOB': 1,
#  'GIGASET_CAPI': 1,
#  'NET_VENDOR_NATSEMI': 1,
#  'NETFILTER_INGRESS': 1,
#  'CRYPTO_DEFLATE': 1,
#  'BCMA_DRIVER_PCI': 1,
#  'VIDEO_PVRUSB2_SYSFS': 1,
#  'NET_PTP_CLASSIFY': 1,
#  'BRANCH_PROFILE_NONE': 1,
#  'NET_VENDOR_TEHUTI': 1,
#  'INET_TUNNEL': 1,
#  'USB_VIDEO_CLASS_INPUT_EVDEV': 1,
#  'DEVPORT': 1,
#  'IR_RC5_DECODER': 1,
#  'UPROBE_EVENTS': 1,
#  'NETFILTER_XT_MATCH_L2TP': 1,
#  'NET_VENDOR_XIRCOM': 1,
#  'HW_RANDOM_MESON': 1,
#  'SCSI_SYM53C8XX_MMIO': 1,
#  'THINKPAD_ACPI_ALSA_SUPPORT': 1,
#  'USB_DEFAULT_PERSIST': 1,
#  'PCMCIA_LOAD_CIS': 1,
#  'X86_THERMAL_VECTOR': 1,
#  'BLK_DEV': 1,
#  'CAPI_TRACE': 1,
#  'COMMON_CLK_XGENE': 1,
#  'IR_JVC_DECODER': 1,
#  'HID_MICROSOFT': 1,
#  'BT_HS': 1,
#  'VIDEO_CX88_VP3054': 1,
#  'SIRFSOC_WATCHDOG': 1,
#  'MOUSE_PS2_SYNAPTICS_SMBUS': 1,
#  'OCFS2_DEBUG_MASKLOG': 1,
#  'BOUNCE': 1,
#  'SECCOMP': 1,
#  'PM_GENERIC_DOMAINS_OF': 1,
#  'TIGON3_HWMON': 1,
#  'XEN_SCRUB_PAGES': 1,
#  'NET_VENDOR_8390': 1,
#  'MOUSE_PS2_SYNAPTICS': 1,
#  'RANDOMIZE_BASE': 1,
#  'SERIO_LIBPS2': 1,
#  'WLAN_VENDOR_QUANTENNA': 1,
#  'UPROBES': 1,
#  'THERMAL_GOV_STEP_WISE': 1,
#  'WLAN_VENDOR_ADMTEK': 1,
#  'XEN_PCIDEV_BACKEND': 1,
#  'HID_CHERRY': 1,
#  'XENFS': 1,
#  'PROC_VMCORE': 1,
#  'PID_NS': 1,
#  'RC_MAP': 1,
#  'X86_MCE_AMD': 1,
#  'BT_DEBUGFS': 1,
#  'XEN_PVHVM': 1,
#  'HVC_DRIVER': 1,
#  'B43_PHY_HT': 1,
#  'X86_NEED_RELOCS': 1,
#  'GENERIC_PINMUX_FUNCTIONS': 1,
#  'MLXSW_SWITCHIB': 1,
#  'NET_VENDOR_HISILICON': 1,
#  'EVENT_TRACING': 1,
#  'TRACING': 1,
#  'SERIO_I8042': 1,
#  'NET_VENDOR_MICREL': 1,
#  'IXGBE_HWMON': 1,
#  'SLAB_MERGE_DEFAULT': 1,
#  'TCP_CONG_BIC': 1,
#  'HW_RANDOM_INTEL': 1,
#  'MTD_OF_PARTS': 1,
#  'NF_CONNTRACK_PROCFS': 1,
#  'PROBE_EVENTS': 1,
#  'SND_CS46XX_NEW_DSP': 1,
#  'NET_VENDOR_AQUANTIA': 1,
#  'THERMAL_WRITABLE_TRIPS': 1,
#  'NET_VENDOR_EXAR': 1,
#  'BNXT_FLOWER_OFFLOAD': 1,
#  'SPARSEMEM_VMEMMAP': 1,
#  'FRAMEBUFFER_CONSOLE': 1,
#  'NF_CT_PROTO_UDPLITE': 1,
#  'MTD_CFI_I1': 1,
#  'PERF_EVENTS_INTEL_UNCORE': 1,
#  'HVC_IRQ': 1,
#  'SFC_MTD': 1,
#  'NETWORK_FILESYSTEMS': 1,
#  'NET_CADENCE': 1,
#  'XEN_BACKEND': 1,
#  'NET_VENDOR_MARVELL': 1,
#  'NET_VENDOR_MICROCHIP': 1,
#  'THINKPAD_ACPI_VIDEO': 1,
#  'RETPOLINE': 1,
#  'NET_VENDOR_CAVIUM': 1,
#  'MLXSW_SPECTRUM_DCB': 1,
#  'ACPI_AC': 1,
#  'HW_RANDOM_AMD': 1,
#  'PNP_DEBUG_MESSAGES': 1,
#  'NET_VENDOR_STMICRO': 1,
#  'NET_VENDOR_EMULEX': 1,
#  'FTRACE': 1,
#  'XEN_GRANT_DEV_ALLOC': 1,
#  'CAN_GW': 1,
#  'MLXSW_SWITCHX2': 1,
#  'ACPI_I2C_OPREGION': 1,
#  'IPV6_SIT': 1,
#  'WIL6210_TRACING': 1,
#  'MTD_CFI_I2': 1,
#  'PM_GENERIC_DOMAINS': 1,
#  'IDE_PROC_FS': 1,
#  'HVC_XEN': 1,
#  'SFC_MCDI_MON': 1,
#  'SCHED_DEBUG': 1,
#  'MICROCODE_INTEL': 1,
#  'RT2800PCI_RT35XX': 1,
#  'RT2800PCI_RT3290': 1,
#  'MOUSE_PS2_TRACKPOINT': 1,
#  'NET_VENDOR_AMAZON': 1,
#  'NET_VENDOR_QUALCOMM': 1,
#  'ARCH_USES_HIGH_VMA_FLAGS': 1,
#  'LCD_CLASS_DEVICE': 1,
#  'UBIFS_FS_ZLIB': 1,
#  'KEYBOARD_ATKBD': 1,
#  'NET_VENDOR_RENESAS': 1,
#  'TOUCHSCREEN_WM9713': 1,
#  'RC_DECODERS': 1,
#  'NET_VENDOR_ROCKER': 1,
#  'BINFMT_SCRIPT': 1,
#  'RENESAS_DMA': 1,
#  'PERF_EVENTS_INTEL_CSTATE': 1,
#  'NET_INGRESS': 1,
#  'MLXSW_CORE_THERMAL': 1,
#  'INFINIBAND_ADDR_TRANS_CONFIGFS': 1,
#  'HID_APPLE': 1,
#  'WLAN_VENDOR_ATMEL': 1,
#  'SQUASHFS_ZLIB': 1,
#  'USB_OHCI_HCD_PCI': 1,
#  'PAGE_TABLE_ISOLATION': 1,
#  'IR_SHARP_DECODER': 1,
#  'NET_VENDOR_RDC': 1,
#  'NF_NAT_PROTO_UDPLITE': 1,
#  'ACPI_PROCESSOR': 1,
#  'USB_HID': 1,
#  'X86_VERBOSE_BOOTUP': 1,
#  'WLAN_VENDOR_ZYDAS': 1,
#  'ELFCORE': 1,
#  'COMPACTION': 1,
#  'NFP_APP_FLOWER': 1,
#  'PERF_EVENTS_INTEL_RAPL': 1,
#  'PM_GENERIC_DOMAINS_SLEEP': 1,
#  'CROSS_MEMORY_ATTACH': 1,
#  'LZO_DECOMPRESS': 1,
#  'XEN_BLKDEV_FRONTEND': 1,
#  'ACPI_BATTERY': 1,
#  'WLAN_VENDOR_ST': 1,
#  'NF_NAT_PROTO_SCTP': 1,
#  'GENERIC_PINCTRL_GROUPS': 1,
#  'SMS_SIANO_RC': 1,
#  'ACPI_CPU_FREQ_PSS': 1,
#  'MTD_MAP_BANK_WIDTH_2': 1,
#  'INPUT_KEYBOARD': 1,
#  'CPU_IDLE_GOV_LADDER': 1,
#  'SERIAL_SC16IS7XX_I2C': 1,
#  'ACPI_FAN': 1,
#  'WATCHDOG_HANDLE_BOOT_ENABLED': 1,
#  'MLXSW_CORE_HWMON': 1,
#  'ACPI_PROCESSOR_IDLE': 1,
#  'DVB_AV7110_OSD': 1,
#  'MICROCODE_OLD_INTERFACE': 1,
#  'XEN_SYS_HYPERVISOR': 1,
#  'NET_VENDOR_ADAPTEC': 1,
#  'BNXT_SRIOV': 1,
#  'INFINIBAND_ADDR_TRANS': 1,
#  'RELOCATABLE': 1,
#  'PRINT_QUOTA_WARNING': 1,
#  'NET_VENDOR_AGERE': 1,
#  'LOGO_LINUX_MONO': 1,
#  'RT2800USB_RT35XX': 1,
#  'BINFMT_ELF': 1,
#  'X86_DEBUG_FPU': 1,
#  'CORE_DUMP_DEFAULT_ELF_HEADERS': 1,
#  'MTRR_SANITIZER': 1,
#  'HW_RANDOM_VIA': 1,
#  'ACPI_REV_OVERRIDE_POSSIBLE': 1,
#  'NET_VENDOR_TI': 1,
#  'X86_INTEL_MEMORY_PROTECTION_KEYS': 1,
#  'WIL6210_DEBUGFS': 1,
#  'MTD_MAP_BANK_WIDTH_1': 1,
#  'FONT_8x8': 1,
#  'BATMAN_ADV_BLA': 1,
#  'TCP_CONG_HTCP': 1,
#  'HID_LOGITECH': 1,
#  'PTP_1588_CLOCK_DTE': 1,
#  'DETECT_HUNG_TASK': 1,
#  'PINCTRL_INGENIC': 1,
#  'HID_EZKEY': 1,
#  'REALTEK_AUTOPM': 1,
#  'FB_MB862XX_I2C': 1,
#  'LEGACY_PTYS': 1,
#  'NET_VENDOR_SAMSUNG': 1,
#  'HT_IRQ': 1,
#  'CRYPTO_MANAGER_DISABLE_TESTS': 1,
#  'THINKPAD_ACPI_HOTKEY_POLL': 1,
#  'TRACE_CLOCK': 1,
#  'NET_VENDOR_OKI': 1,
#  'MOUSE_PS2_LIFEBOOK': 1,
#  'MOUSE_PS2_SMBUS': 1,
#  'TOUCHSCREEN_WM9712': 1,
#  'OCFS2_FS_O2CB': 1,
#  'ARCH_HAS_PKEYS': 1,
#  'NET_VENDOR_REALTEK': 1,
#  'XEN_PCIDEV_FRONTEND': 1,
#  'XEN_512GB': 1,
#  'DMIID': 1,
#  'EXT4_USE_FOR_EXT2': 1,
#  'BT_BREDR': 1,
#  'IXGBE_DCA': 1,
#  'MOUSE_PS2_LOGIPS2PP': 1,
#  'XEN_NETDEV_FRONTEND': 1,
#  'IGB_HWMON': 1,
#  'IDE_GD_ATA': 1,
#  'SYS_HYPERVISOR': 1,
#  'BCMA_HOST_PCI': 1,
#  'VIRTUALIZATION': 1,
#  'NET_VENDOR_SEEQ': 1,
#  'NET_VENDOR_SUN': 1,
#  'CONTEXT_SWITCH_TRACER': 1,
#  'NET_VENDOR_BROCADE': 1,
#  'MOUSE_PS2_BYD': 1,
#  'NET_VENDOR_FUJITSU': 1,
#  'MLXSW_MINIMAL': 1,
#  'INTEL_SCU_IPC_UTIL': 1,
#  'DEVMEM': 1,
#  'XEN_SYMS': 1,
#  'NET_NS': 1,
#  'USB_XHCI_PCI': 1,
#  'KXSD9_I2C': 1,
#  'IOSCHED_DEADLINE': 1,
#  'CAN_RAW': 1,
#  'B43_HWRNG': 1,
#  'UBIFS_FS_LZO': 1,
#  'DRM_KMS_FB_HELPER': 1,
#  'KXSD9_SPI': 1,
#  'MOUSE_PS2_FOCALTECH': 1,
#  'PTP_1588_CLOCK': 1,
#  'IDE_GD': 1,
#  'NET_VENDOR_HP': 1,
#  'RSI_DEBUGFS': 1,
#  'INPUT_LEDS': 1,
#  'PTP_1588_CLOCK_KVM': 1,
#  'MANDATORY_FILE_LOCKING': 1,
#  'DM_CACHE_SMQ': 1,
#  'E1000E_HWTS': 1,
#  'VIDEO_EM28XX_RC': 1,
#  'NET_VENDOR_SIS': 1,
#  'THERMAL_OF': 1,
#  'NET_VENDOR_ATHEROS': 1,
#  'VT_HW_CONSOLE_BINDING': 1,
#  'PPS': 1,
#  'HYPERV_STORAGE': 1,
#  'I2C_COMPAT': 1,
#  'USB_ARMLINUX': 1,
#  'SECCOMP_FILTER': 1,
#  'WLAN_VENDOR_MARVELL': 1,
#  'MOUSE_PS2_CYPRESS': 1,
#  'CAN_CALC_BITTIMING': 1,
#  'RTLWIFI_DEBUG': 1,
#  'ENABLE_WARN_DEPRECATED': 1,
#  'BNX2X_SRIOV': 1,
#  'THERMAL_DEFAULT_GOV_STEP_WISE': 1,
#  'RING_BUFFER': 1,
#  'WIL6210_ISR_COR': 1,
#  'NET_VENDOR_I825XX': 1,
#  'AIC79XX_DEBUG_ENABLE': 1,
#  'DRM_FBDEV_EMULATION': 1,
#  'AIC94XX_DEBUG': 1,
#  'XEN_AUTO_XLATE': 1,
#  'MQ_IOSCHED_DEADLINE': 1,
#  'SND_SUPPORT_OLD_API': 1,
#  'NET_VENDOR_SILAN': 1,
#  'INET_XFRM_MODE_BEET': 1,
#  'SWAP': 1,
#  'NET_VENDOR_CISCO': 1,
#  'RSI_SDIO': 1,
#  'IR_RC6_DECODER': 1,
#  'HID_CYPRESS': 1,
#  'LZO_COMPRESS': 1,
#  'NET_VENDOR_NVIDIA': 1,
#  'NET_VENDOR_DLINK': 1,
#  'XEN_DEV_EVTCHN': 1,
#  'UTS_NS': 1,
#  'DNOTIFY': 1,
#  'INOTIFY_USER': 1,
#  'ENABLE_MUST_CHECK': 1,
#  'BT_LE': 1,
#  'SFC_MCDI_LOGGING': 1,
#  'MSDOS_PARTITION': 1,
#  'NET_PACKET_ENGINE': 1,
#  'MQ_IOSCHED_KYBER': 1,
#  'HW_RANDOM_CAVIUM': 1,
#  'ZLIB_DEFLATE': 1,
#  'USB_EHCI_PCI': 1,
#  'SCHED_OMIT_FRAME_POINTER': 1,
#  'RT2800PCI_RT33XX': 1,
#  'SERIAL_SC16IS7XX_CORE': 1,
#  'XEN_COMPAT_XENFS': 1,
#  'IR_NEC_DECODER': 1,
#  'EFI_PARTITION': 1,
#  'NET_VENDOR_EZCHIP': 1,
#  'LOGO_LINUX_VGA16': 1,
#  'X86_MPPARSE': 1,
#  'ACPI_BUTTON': 1,
#  'WLAN_VENDOR_MEDIATEK': 1,
#  'UNUSED_SYMBOLS': 1,
#  'VIDEO_SAA7134_RC': 1,
#  'TRACING_EVENTS_GPIO': 1,
#  'UEVENT_HELPER': 1,
#  'MOUSE_ELAN_I2C_I2C': 1,
#  'SUSPEND': 1,
#  'RANDOMIZE_MEMORY': 1,
#  'MICROCODE': 1,
#  'IR_SONY_DECODER': 1,
#  'NET_VENDOR_HUAWEI': 1,
#  'B43_PHY_N': 1,
#  'HID_CHICONY': 1,
#  'NOP_TRACER': 1,
#  'TCP_CONG_WESTWOOD': 1,
#  'LWTUNNEL_BPF': 1,
#  'MYRI10GE_DCA': 1,
#  'NF_CT_PROTO_SCTP': 1,
#  'NET_VENDOR_ARC': 1,
#  'IR_SANYO_DECODER': 1,
#  'PWRSEQ_SIMPLE': 1,
#  'VIDEO_CX88_ENABLE_VP3054': 1,
#  'X86_MCE_INTEL': 1,
#  'SFC_SRIOV': 1,
#  'SCSI_SAS_HOST_SMP': 1,
#  'X86_PKG_TEMP_THERMAL': 1,
#  'OCFS2_FS_STATS': 1,
#  'CFG80211_DEFAULT_PS': 1,
#  'IPV6_NDISC_NODETYPE': 1,
#  'TCP_CONG_CUBIC': 1,
#  'INET_XFRM_MODE_TRANSPORT': 1,
#  'SUSPEND_FREEZER': 1,
#  'PWRSEQ_EMMC': 1,
#  'FIRMWARE_IN_KERNEL': 1,
#  'ACPI_THERMAL': 1,
#  'INET6_XFRM_MODE_BEET': 1,
#  'NET_VENDOR_FREESCALE': 1,
#  'CRYPTO_ECHAINIV': 1,
#  'HID_MONTEREY': 1,
#  'NET_VENDOR_ALTEON': 1,
#  'NF_CT_PROTO_DCCP': 1,
#  'ARM_SCPI_POWER_DOMAIN': 1}

# %%
test['THERMAL']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-d7eca0c68bd7> in <module>
# ----> 1 test['THERMAL']
#
# KeyError: 'THERMAL'

# %%
solu = potential_configurations[100]
create_config_xp(solu)

# %%
def get_var(option):
    for k, v in variables.items():
        if v == option:
            return k

# %%
get_var("THERMAL")
# Out:
# 3303

# %%
fla = CNF(DIMACS_FLA)
SOLU_SIZE = 1
m = []
with Solver(bootstrap_with=fla.clauses) as s:
    for no, k in enumerate(s.enum_models(assumptions=[-get_var("THERMAL")]), 1):
        if no > SOLU_SIZE:
            break
        m.append(k)

# %%
s1 = list()
with Solver(bootstrap_with=fla.clauses) as s:
    for no, k in enumerate(s.enum_models(assumptions=[-get_var("THERMAL")]), 1):
        if no > 1:
            break
        s1.append(k)

# %%
s1 = list(map(lambda x: {variables[k] for k in x if k > 0 and k in variables}, s1))

# %%
create_config_xp(s1[0])

# %%
len(m[0])
# Out:
# 76662

# %%
m = list(map(lambda x: {variables[k] for k in x if k > 0 and k in variables}, m))

# %%
# Get rid of redundant solutions
lon = len(m)
res = list()
current = 0
in_list = True
while(in_list):
    res.append(m[current])
    for k in range(current + 1, lon):
        if m[current] != m[k]:
            current = k
            break
        if k == lon - 1:
            in_list = False
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-95475f572b13> in <module>
#       6 while(in_list):
#       7     res.append(m[current])
# ----> 8     for k in range(current + 1, lon):
#       9         if m[current] != m[k]:
#      10             current = k
#
# KeyboardInterrupt:

# %%
len(m[0])
# Out:
# 2193

# %%
create_config_xp(m[0])

# %%
s = set()
for k in res:
    s.add("THERMAL" in k)
s
# Out:
# {False}

# %%
diff_test = dict()
for solu in res:
    create_config_xp(solu)
    os.system("make olddefconfig -C {}".format(CONFIG_DIR))
    new_config = get_dict("{}/.config".format(CONFIG_DIR))
    # diff
    if len(new_config) > len(solu):
        diff = set(new_config) - solu
        for feat in diff:
            if feat in diff_test:
                diff_test[feat] += 1
            else:
                diff_test[feat] = 1

# %%
for elt in m[0]:
    if 'THERMAL' in elt:
        print(elt)
# Out:
# THERMAL
# THERMAL_GOV_STEP_WISE
# THERMAL_EMERGENCY_POWEROFF_DELAY_MS
# HISI_THERMAL
# THERMAL_DEFAULT_GOV_STEP_WISE

# %%
for elt in potential_configurations[0]:
    if 'THERMAL' in elt:
        print(elt)
# Out:
# THERMAL_EMERGENCY_POWEROFF_DELAY_MS

# %%
create_config_xp(m[0])

# %%
create_config_xp(potential_configurations[0])
